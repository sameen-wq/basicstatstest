# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
df=pd.read_csv('grades.csv')
df.head()
# Out:
#                              student_id  assignment1_grade  \
# 0  B73F2C11-70F0-E37D-8B10-1D20AFED50B1          92.733946
# 1  98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1          86.790821
# 2  D0F62040-CEB0-904C-F563-2F8620916C4E          85.512541
# 3  FFDF2B2C-F514-EF7F-6538-A6A53518E9DC          86.030665
# 4  5ECBEEB6-F1CE-80AE-3164-E45E99473FB4          64.813800
#
#           assignment1_submission  assignment2_grade  \
# 0  2015-11-02 06:55:34.282000000          83.030552
# 1  2015-11-29 14:57:44.429000000          86.290821
# 2  2016-01-09 05:36:02.389000000          85.512541
# 3  2016-04-30 06:50:39.801000000          68.824532
# 4  2015-12-13 17:06:10.750000000          51.491040
#
#           assignment2_submission  assignment3_grade  \
# 0  2015-11-09 02:22:58.938000000          67.164441
# 1  2015-12-06 17:41:18.449000000          69.772657
# 2  2016-01-09 06:39:44.416000000          68.410033
# 3  2016-04-30 17:20:38.727000000          61.942079
# ...

# %%
print('THere are {} rows and {} columns'.format(df.shape[0], df.shape[1]))
# Out:
# THere are 2315 rows and 13 columns

# %%
early_finishers=df[pd.to_datetime(df['assignment1_submission']) < '2016']
early_finishers.head()
# Out:
#                              student_id  assignment1_grade  \
# 0  B73F2C11-70F0-E37D-8B10-1D20AFED50B1          92.733946
# 1  98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1          86.790821
# 4  5ECBEEB6-F1CE-80AE-3164-E45E99473FB4          64.813800
# 5  D09000A0-827B-C0FF-3433-BF8FF286E15B          71.647278
# 8  C9D51293-BD58-F113-4167-A7C0BAFCB6E5          66.595568
#
#           assignment1_submission  assignment2_grade  \
# 0  2015-11-02 06:55:34.282000000          83.030552
# 1  2015-11-29 14:57:44.429000000          86.290821
# 4  2015-12-13 17:06:10.750000000          51.491040
# 5  2015-12-28 04:35:32.836000000          64.052550
# 8  2015-12-25 02:29:28.415000000          52.916454
#
#           assignment2_submission  assignment3_grade  \
# 0  2015-11-09 02:22:58.938000000          67.164441
# 1  2015-12-06 17:41:18.449000000          69.772657
# 4  2015-12-14 12:25:12.056000000          41.932832
# 5  2016-01-03 21:05:38.392000000          64.752550
# ...

# %%
late_finishers=df[~df.index.isin(early_finishers.index)]
late_finishers.head()
# Out:
#                              student_id  assignment1_grade  \
# 2  D0F62040-CEB0-904C-F563-2F8620916C4E          85.512541
# 3  FFDF2B2C-F514-EF7F-6538-A6A53518E9DC          86.030665
# 6  3217BE3F-E4B0-C3B6-9F64-462456819CE4          87.498744
# 7  F1CB5AA1-B3DE-5460-FAFF-BE951FD38B5F          80.576090
# 9  E2C617C2-4654-622C-AB50-1550C4BE42A0          59.270882
#
#           assignment1_submission  assignment2_grade  \
# 2  2016-01-09 05:36:02.389000000          85.512541
# 3  2016-04-30 06:50:39.801000000          68.824532
# 6  2016-03-05 11:05:25.408000000          69.998995
# 7  2016-01-24 18:24:25.619000000          72.518481
# 9  2016-03-06 12:06:26.185000000          59.270882
#
#           assignment2_submission  assignment3_grade  \
# 2  2016-01-09 06:39:44.416000000          68.410033
# 3  2016-04-30 17:20:38.727000000          61.942079
# 6  2016-03-09 07:29:52.405000000          55.999196
# 7  2016-01-27 13:37:12.943000000          65.266633
# ...

# %%
early=df[pd.to_datetime(df['assignment3_submission']) < '2016']
early.head()
# Out:
#                               student_id  assignment1_grade  \
# 0   B73F2C11-70F0-E37D-8B10-1D20AFED50B1          92.733946
# 1   98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1          86.790821
# 4   5ECBEEB6-F1CE-80AE-3164-E45E99473FB4          64.813800
# 11  B017B4A6-1F41-9D46-A040-21B0D270D4BE          76.670469
# 15  24827B50-2FC2-E4B0-E2A0-1989E17749B3          14.959603
#
#            assignment1_submission  assignment2_grade  \
# 0   2015-11-02 06:55:34.282000000          83.030552
# 1   2015-11-29 14:57:44.429000000          86.290821
# 4   2015-12-13 17:06:10.750000000          51.491040
# 11  2015-10-05 02:11:05.947000000          68.573422
# 15  2015-11-17 01:16:07.800000000          14.459603
#
#            assignment2_submission  assignment3_grade  \
# 0   2015-11-09 02:22:58.938000000          67.164441
# 1   2015-12-06 17:41:18.449000000          69.772657
# 4   2015-12-14 12:25:12.056000000          41.932832
# 11  2015-10-11 23:08:01.288000000          69.273422
# ...

# %%
late=df[~df.index.isin(early.index)]
late.head()print(early['assignment1_grade'].mean())
print(late['assignment1_grade'].mean())
# Out:
#                              student_id  assignment1_grade  \
# 2  D0F62040-CEB0-904C-F563-2F8620916C4E          85.512541
# 3  FFDF2B2C-F514-EF7F-6538-A6A53518E9DC          86.030665
# 5  D09000A0-827B-C0FF-3433-BF8FF286E15B          71.647278
# 6  3217BE3F-E4B0-C3B6-9F64-462456819CE4          87.498744
# 7  F1CB5AA1-B3DE-5460-FAFF-BE951FD38B5F          80.576090
#
#           assignment1_submission  assignment2_grade  \
# 2  2016-01-09 05:36:02.389000000          85.512541
# 3  2016-04-30 06:50:39.801000000          68.824532
# 5  2015-12-28 04:35:32.836000000          64.052550
# 6  2016-03-05 11:05:25.408000000          69.998995
# 7  2016-01-24 18:24:25.619000000          72.518481
#
#           assignment2_submission  assignment3_grade  \
# 2  2016-01-09 06:39:44.416000000          68.410033
# 3  2016-04-30 17:20:38.727000000          61.942079
# 5  2016-01-03 21:05:38.392000000          64.752550
# 6  2016-03-09 07:29:52.405000000          55.999196
# ...

# %%
print(early['assignment1_grade'].mean())
print(late['assignment1_grade'].mean())
# Out:
# 74.77834109055549
# 74.32722472788728

# %%
from scipy.stats import ttest_ind
ttest_ind(early['assignment1_grade'], late['assignment1_grade'])
# Out:
# TtestResult(statistic=0.6616567704701553, pvalue=0.5082571228587918, df=2313.0)

# %%
df1=pd.DataFrame([np.random.random(100) for x in range(100)])
df1.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.954793  0.338776  0.592099  0.687551  0.823632  0.569932  0.177023
# 1  0.350429  0.368760  0.033954  0.086124  0.757380  0.747055  0.635559
# 2  0.635630  0.159884  0.381355  0.932193  0.316736  0.499863  0.009898
# 3  0.944352  0.712755  0.783243  0.452760  0.221199  0.132792  0.054184
# 4  0.147683  0.164149  0.317436  0.869477  0.441535  0.199818  0.754188
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.883645  0.756351  0.847917  ...  0.214933  0.965143  0.004711  0.673884
# 1  0.527717  0.996378  0.447194  ...  0.531513  0.866663  0.087789  0.975590
# 2  0.884593  0.944530  0.592108  ...  0.337597  0.693889  0.317133  0.325726
# 3  0.727225  0.301473  0.164570  ...  0.464694  0.451743  0.494410  0.477593
# 4  0.132279  0.779825  0.991313  ...  0.357125  0.277374  0.754242  0.472327
#
#          94        95        96        97        98        99
# ...

# %%
df2=pd.DataFrame([np.random.random(100) for x in range(100)])

# %%
def test_columns(alpha=0.1):
    num_diff=0
    for col in df1.columns:
        teststat,pval=ttest_ind(df1[col],df2[col])
        if pval<=alpha:
        
            print("Col {} is statistically significantly different at alpha={}, pval={}".format(col,alpha,pval))
            num_diff=num_diff+1
    print("Total number different was {}, which is {}%".format(num_diff,float(num_diff)/len(df1.columns)*100))

test_columns()
# Out:
# Col 5 is statistically significantly different at alpha=0.1, pval=0.07600363712717959
# Col 15 is statistically significantly different at alpha=0.1, pval=0.0412118284525832
# Col 39 is statistically significantly different at alpha=0.1, pval=0.023951400274668782
# Col 70 is statistically significantly different at alpha=0.1, pval=0.045190631368822495
# Col 72 is statistically significantly different at alpha=0.1, pval=0.07276159514864766
# Col 73 is statistically significantly different at alpha=0.1, pval=0.02602693882612672
# Col 87 is statistically significantly different at alpha=0.1, pval=0.05229910174706108
# Col 99 is statistically significantly different at alpha=0.1, pval=0.05229968891743713
# Total number different was 8, which is 8.0%

# %%
test_columns(0.05)
# Out:
# Col 15 is statistically significantly different at alpha=0.05, pval=0.0412118284525832
# Col 39 is statistically significantly different at alpha=0.05, pval=0.023951400274668782
# Col 70 is statistically significantly different at alpha=0.05, pval=0.045190631368822495
# Col 73 is statistically significantly different at alpha=0.05, pval=0.02602693882612672
# Total number different was 4, which is 4.0%

# %%
def test_cols(alpha=0.01):
    col_diff=0
    for col in df2.columns:
        teststat,pval=ttest_ind(df1[col],df2[col])
        if pval<=alpha:
            print('col{} is diff at alpha={}, pval={}'.format(col,alpha,pval))
            col_diff+=1
    print('total number diff col {}'.format(col_diff))
test_cols()
# Out:
# total number diff col 0

# %%
test_cols(0.05)
# Out:
# col15 is diff at alpha=0.05, pval=0.0412118284525832
# col39 is diff at alpha=0.05, pval=0.023951400274668782
# col70 is diff at alpha=0.05, pval=0.045190631368822495
# col73 is diff at alpha=0.05, pval=0.02602693882612672
# total number diff col 4

# %%
df3=pd.DataFrame(np.random.chisquare(df=1,size=100) for x in range(100))
test_columns()
# Out:
# Col 5 is statistically significantly different at alpha=0.1, pval=0.07600363712717959
# Col 15 is statistically significantly different at alpha=0.1, pval=0.0412118284525832
# Col 39 is statistically significantly different at alpha=0.1, pval=0.023951400274668782
# Col 70 is statistically significantly different at alpha=0.1, pval=0.045190631368822495
# Col 72 is statistically significantly different at alpha=0.1, pval=0.07276159514864766
# Col 73 is statistically significantly different at alpha=0.1, pval=0.02602693882612672
# Col 87 is statistically significantly different at alpha=0.1, pval=0.05229910174706108
# Col 99 is statistically significantly different at alpha=0.1, pval=0.05229968891743713
# Total number different was 8, which is 8.0%
